# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("traces.db")

# %%
df = pd.read_sql_query(
    "SELECT name, input_tokens FROM spans WHERE input_tokens IS NOT NULL",
    conn,
)
df
# Out:
#   name  input_tokens
# 0  llm          7111
# 1  llm          7111
# 2  llm          7111
# 3  llm          7111
# 4  llm          7111
